# %%
from sympy import *
g, m, k, l0, x  = symbols('g, m, k, l0, x') 
g=10
m=80
k=400
l0 =13
v = (2/m*(- m*g*x - k*((25-x-1)-l0)**2/2  + m*g*(25+1)))**0.5

plot(v, (x, 1, 26))


dv=diff(v,x)
sln=solve(simplify(dv),x)
simplify(v.subs(x,sln[0]))
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# 17.8885438199983
